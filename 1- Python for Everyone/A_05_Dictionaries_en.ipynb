# %% [markdown]
# **(1)** Create a dictionary with 7 days. Ask the user to choose 2 different days by listing the (e.g. "12" for Monday and Tuesday). Delete the user-selected days from the dictionary and print the remaining 5 days on the screen.<br><br>

# %%
days = {1: 'Monday',
        2: 'Tuesday',
        3: 'Wednesday',
        4: 'Thursday',
        5: 'Friday',
        6: 'Saturday',
        7: 'Sunday'}


selected = input('Write two days to delete (e.g. "25"):')

days.pop(int(selected[0]))
days.pop(int(selected[1]))

print(days)
# Out:
# Write two days to delete (e.g. "25"):25
# {1: 'Monday', 3: 'Wednesday', 4: 'Thursday', 6: 'Saturday', 7: 'Sunday'}

# %% [markdown]
# **(2)**  Create a dictionary with the following personnel. Use names as keys.
#
# |Name|Age|Sex|
# |-|-|-|
# |John|25|Male|
# |Lisa|28|Female|
# |Linda|32|Female|
# |Michael|41|Male|

# %%
personnel = {'John': [25, 'Male'], 'Lisa': [28, 'Female'], 'Linda': [32, 'Female'], 'Michael': [41, 'Male']}

# %%
personnel
# Out:
# {'John': [25, 'Male'],
#  'Linda': [32, 'Female'],
#  'Lisa': [28, 'Female'],
#  'Michael': [41, 'Male']}

# %% [markdown]
# **(3)** Add child information to Michael and Linda. Michael has two children (Karen (age : 12, female) and Greg (age : 7, male) and Linda has one child (Susan (age: 6, female))

# %%
personnel['Michael'].append({'Children': {'Karen': [12, 'Female'], 'Greg':[7, 'Male']}})
personnel['Linda'].append({'Children': {'Susan': [6, 'Female']}})

# %%
personnel
# Out:
# {'John': [25, 'Male'],
#  'Linda': [32, 'Female', {'Children': {'Susan': [6, 'Female']}}],
#  'Lisa': [28, 'Female'],
#  'Michael': [41,
#   'Male',
#   {'Children': {'Greg': [7, 'Male'], 'Karen': [12, 'Female']}}]}

# %% [markdown]
# **(4)** Print the names of Michael's children in a list.

# %%
list(personnel['Michael'][2]['Children'].keys())
# Out:
# ['Karen', 'Greg']
