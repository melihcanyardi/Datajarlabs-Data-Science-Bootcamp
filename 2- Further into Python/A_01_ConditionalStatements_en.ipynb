# %% [markdown]
# **(1)** Please get Celcius or Fahrenheit degrees from users and type a code to convert these heat units to each other.
#
#     For conversion, please use this formula: C = (5/9) * (F - 32)
#
#         Example : "40C" --> "104F"
#                   "52F" --> "11.1C"

# %%
degree = input("Please enter the degree in either Celcius or Fahrenheit (e.g. 40C, 52F): ")

if degree[-1] == 'C':
  print("{:.1f}F".format(int(degree[:-1])*(9/5) + 32))
else:
  print("{:.1f}C".format((int(degree[:-1]) - 32) * (5/9)))
# Out:
# Please enter the degree in either Celcius or Fahrenheit (e.g. 40C, 52F): 52F
# 11.1C

# %% [markdown]
# **(2)** A company decided to give a bonus of 5% to the employees if his/her year of service is more than 5 years.
# Ask the user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Please enter your salary: "))
year = int(input("Please enter your year of service: "))

if year > 5:
  bonus = salary*.05
  print("Net bonus amount: {}".format(bonus))
else:
  print("No bonus")
# Out:
# Please enter your salary: 5000
# Please enter your year of service: 7
# Net bonus amount: 250.0

# %% [markdown]
# **(3)** Take input of ages of 3 people by the user and determine the oldest and youngest among them.

# %%
age_1 = int(input("Enter the age of first person: "))
age_2 = int(input("Enter the age of second person: "))
age_3 = int(input("Enter the age of third person: "))

if (age_1 > age_2) and (age_1 > age_3):
  if age_2 > age_3:
    print("First person is the oldest, third person is the youngest.")
  else:
    print("First person is the oldest, second person is the youngest.")
elif (age_2 > age_1) and (age_2 > age_3):
  if age_1 > age_3:
    print("Second person is the oldest, third person is the youngest.")
  else:
    print("Second person is the oldest, first person is the youngest.")
else:
  if age_1 > age_2:
    print("Third person is the oldest, second person is the youngest.")
  else:
    print("Third person is the oldest, first person is the youngest.")
# Out:
# Enter the age of first person: 10
# Enter the age of second person: 20
# Enter the age of third person: 30
# Third person is the oldest, first person is the youngest.

# %% [markdown]
# **(4)** A student will not be allowed to attend to the exam if his / her attendance to classes is less than 75%. Take followings input from the user:
# - Number of classes held,
# - Number of classes attended.
#
#     Then, print the percentage of classes attended and whether the student is allowed to attend in an exam or not.

# %%
held = int(input("Please enter the number of classes held: "))
attended = int(input("Please enter the number of classes attended: "))

percentage = attended/held*100
print("The percentage of classes attended is {}%.".format(percentage))

if percentage > 75:
  print("The student is allowed to attend the exam.")
else:
  print("The student is not allowed to attend the exam.")
# Out:
# Please enter the number of classes held: 10
# Please enter the number of classes attended: 8
# The percentage of classes attended is 80.0%.
# The student is allowed to attend the exam.

# %% [markdown]
# **(5)** In this exercise, you will create a program that reads a letter of the alphabet from the user. According to the answer:
#
# - If the user enters `a, e, i, o, u`, then your program should display a message indicating that the entered letter is a vowel.
# - If the user enters `y`, then your program should display a message indicating that y is sometimes a vowel and sometimes a consonant.
# - Otherwise, your program should display a message indicating that the letter is a consonant.

# %%
letter = input("Please enter a letter: ")

if letter in ['a', 'e', 'i', 'o', 'u']:
  print("The entered letter is a vowel.")
elif letter == "y":
  print("y is sometimes a vowel and sometimes a consonant.")
else:
  print("The letter is a consonant.")
# Out:
# Please enter a letter: p
# The letter is a consonant.
